# %% [markdown]
# ### AT&T Data Science Club Bothell Worksheet #1

# %%
# import packages
import pandas as pd

# %%
# import the data
salaries = pd.read_csv('data/survey_results_public.csv')
pd.set_option('display.max_columns', None)
salaries.head(5)

# %%
salaries['TechEndorse_2'].head(5)

# %%
for column in salaries.columns:
    print(column)

# %%
schema = pd.read_csv('data/survey_results_schema.csv')
schema.head(15)

# %% [markdown]
# __Question 1:__ Before you take a look at the data, look at the columns of the dataset. What are some interesting columns that stood out to you?

# %%
# find me the most cooked person on this list

# %%
# find all employees

# %%
# how many vibe coders are there

# %%
# take a look at the schema and find out what it means
